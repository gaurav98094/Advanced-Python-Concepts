# %%
import requests


class Employee:
    """A sample Employee class"""

    raise_amt = 1.05

    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay

    @property
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)

    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)

    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)

    def monthly_schedule(self, month):
        response = requests.get(f'http://company.com/{self.last}/{month}')
        if response.ok:
            return response.text
        else:
            return 'Bad Response!'

# %%
emp = Employee('Gaurav','Kandel',1000)

# %%
emp.monthly_schedule('June')
# Out:
# '<!DOCTYPE html><!-- Last Published: Sun May 26 2024 13:50:45 GMT+0000 (Coordinated Universal Time) -->\n<html data-wf-domain="www.govastly.com" data-wf-page="6564b232db8e4c317cf3df7e" data-wf-site="655f8101c745bce7084eb1ff" lang="en">\n  <head>\n    <meta charset="utf-8" />\n    <title>Vastly | The all-in-one Solution as a Service</title>\n    <meta content="Vastly empowers organizations with the tools, people, process &amp; technology they need to create enterprise-level digital experiences." name="description" />\n    <meta content="width=device-width, initial-scale=1" name="viewport" />\n    <link href="https://assets-global.website-files.com/655f8101c745bce7084eb1ff/css/vastly-marketing.3ef4c4b51.min.css" rel="stylesheet" type="text/css" />\n    <style>\n      @media (min-width:992px) {\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79baae8"] {\n          opacity: 0;\n        }\n      }\n\n      @media (max-width:991px) and (min-width:768px) {\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79baae8"] {\n          opacity: 0;\n        }\n      }\n\n      @media (max-width:767px) and (min-width:480px) {\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79baae9"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79baaf8"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79bab06"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79bab14"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79bab1f"] {\n          opacity: 0;\n        }\n      }\n\n      @media (max-width:479px) {\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79baae9"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79baaf8"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79bab06"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79bab14"] {\n          opacity: 0;\n        }\n\n        html.w-mod-js:not(.w-mod-ix) [data-w-id="efb1ba48-6570-7c51-1be1-7451c79bab1f"] {\n          opacity: 0;\n        }\n      }\n    </style>\n    <link href="https://fonts.googleapis.com" rel="preconnect" />\n    <link href="https://fonts.gstatic.com" rel="preconnect" crossorigin="anonymous" />\n    <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>\n    <script type="text/javascript">\n      WebFont.load({\n        google: {\n          families: ["Manrope:200,300,regular,500,600,700,800", "Work Sans:regular", "Bebas Neue:regular", "Jost:regular"]\n        }\n      });\n    </script>\n    <script type="text/javascript">\n      ! function(o, c) {\n        var n = c.documentElement,\n          t = " w-mod-";\n        n.className += t + "js", ("ontouchstart" in o || o.DocumentTouch && c instanceof DocumentTouch) && (n.className += t + "touch")\n      }(window, document);\n    </script>\n    <link href="https://assets-global.website-files.com/655f8101c745bce7084eb1ff/65f93d3a81d02a124b3a6e69_vastly-favicon-32x32.png" rel="shortcut icon" type="image/x-icon" />\n    <link href="https://assets-global.website-files.com/655f8101c745bce7084eb1ff/65f93d894d56080de93543bd_Untitled%20design%20(9).png" rel="apple-touch-icon" />\n    <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-74DJK8G5Q6"></script>\n    <script type="text/javascript">\n      window.dataLayer = window.dataLayer || [];\n\n      function gtag() {\n        dataLayer.push(arguments);\n      }\n      gtag(\'js\', new Date());\n      gtag(\'set\', \'developer_id.dZG ...

# %%
import unittest
from unittest.mock import patch

class TestEmployee(unittest.TestCase):
    @classmethod
    def setUpClass(cls) -> None:
        return 'Setup CLass'
    
    @classmethod
    def tearDownClass(cls) -> None:
        return 'TearDown Class'

    def setUp(self):
        print('SetUp')
        self.emp1 = Employee('Gaurav','Kandel',10000)
    
    def tearDown(self) -> None:
        print('Tear Down')

    
    def test_email(self):
        self.assertequal(self.emp1.email,'Gaurav.kandel@gmail.com')
        self.emp1.first='GK'
    

    def test_monthly_schedule(self):
